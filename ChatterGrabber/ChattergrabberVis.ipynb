# %% [markdown]
# # ChatterGrabber Quick Visualization

# %% [markdown]
# ### Libraries and dependencies

# %%
import operator
import urllib

import pandas as pd
import matplotlib.pyplot as plt

from random import shuffle, sample
from datetime import timedelta
from dateutil import parser
from matplotlib.dates import DateFormatter, date2num, num2date
from copy import deepcopy
from time import sleep

# %matplotlib inline

# %% [markdown]
# ### Lat/lon box and category declarations

# %%
#Precise VA box, includes adjacent states within bounds
vaBox = {'lat1':36.533333,'lat2':39.466667,'lon1':-88.2807,'lon2':-88.2807}
#Chicago + outlying metro area
chiBox = {'lat1':41.4075,'lat2':42.4055,'lon1':-88.2807,'lon2':-87.1532}
#USA sample from east coast, west to Chicago
eTimeBox = {'lat1':24.544701,'lat2':49.002389,'lon1':-88.2807,'lon2':-66.949778}
#From original NRV experiment
nrvBox = {'lat1':37.046774,'lat2':37.370521,'lon1':-80.705566,'lon2':-79.683838}
#From DH's arlington experiment
#https://www.google.com/maps/dir/'38.83108,-77.17374'/'38.92492,-77.04624'/@38.8717225,-77.1166921,12z/data=!4m9!4m8!1m3!2m2!1d-77.17374!2d38.83108!1m3!2m2!1d-77.04624!2d38.92492
novaBox = {'lat1':38.83108,'lat2':38.92492,'lon1':-77.17374,'lon2':-77.04624}
#Troutdale, OR box
troutBox = {'lat1':45.328068,'lat2':45.734617,'lon1':-122.756426,'lon2':-122.025206}

noroCats = {1:"No Suspected Infectious Illness",2:"Suspected Infectious Illness",3:"Suspected Infectious GI Illness"}
gunCats = {1:"Irrelevant",2:'First Hand',3:'Media Related'}

# %% [markdown]
# ### File declarations

# %%
giAll = {'name':'Virginia Norovirus Posts','file':"bigGIHunter_CollectedTweets.csv",'cats':noroCats}
gunAll = {'name':'Firearm Violence Posts','file':"gunTracker_CollectedTweets.csv",'cats':gunCats}
novaAll = {'name':'General Tweets','file':"HealeysHunter_CollectedTweets.csv",'cats':'null'}
vaccScores =  {'name':'VaccAut Scoring Set','file':"vaccAutNLPScores.csv",'cats':'null'}
vaccData =  {'name':'VaccAut Collected Tweets','file':"vaccAut_CollectedTweets.csv",'cats':'null'}
allData = {giAll['name']:giAll,gunAll['name']:gunAll,novaAll['name']:novaAll,vaccData['name']:vaccData,vaccScores['name']:vaccScores}

for exp in allData.keys():
    allData[exp]['data'] = pd.DataFrame.from_csv(allData[exp]['file'],index_col='id')

# %% [markdown]
# ### Print data sample

# %%
def printSample(data,title,length):
    characters = 100
    indexed = list(data.index)
    shuffle(indexed)
    for pos in indexed[:length]:
        print '\t',data.ix[pos]['text'][:characters]+(len(data.ix[pos]['text'])>characters)*'...'
    print '\n'

# %% [markdown]
# ### Create dataframe subsets by location

# %%
def getGeoSub(dataIn,box,prefix):
    dataOut = deepcopy(dataIn)
    dataOut['name'] = prefix + ' ' + dataOut['name']
    data = dataOut['data']
    data = data[(data.lat > box['lat1']) & (data.lat < box['lat2']) & (data.lon > box['lon1']) & (data.lon < box['lon2'])]
    dataOut['data'] = data
    return dataOut

# %% [markdown]
# ### Create dataframe subsets by category

# %%
def getCatSub(dataIn,categories,cat):
    catCol = 'nltkCat'
    dataOut = deepcopy(dataIn)
    dataOut['name'] = categories[cat] + ' ' + dataOut['name']
    data = dataOut['data']
    data = data[data[catCol] == cat]
    dataOut['data'] = data
    return dataOut

# %% [markdown]
# ### Trim data range by start/stop points

# %%
def trimRange(start,end,collected):
    start = parser.parse(start)
    end = parser.parse(end)
    if start > end:
        start,end = end,start
    holder = deepcopy(collected)
    holder['data']['timeStamp'] = [parser.parse(point) for point in holder['data']['created_at']]
    data = holder['data'][(holder['data']['timeStamp'] >= start) & (holder['data']['timeStamp'] <= end)]
    holder['data'] = data
    return holder

# %% [markdown]
# ### Truncate Tweets by hour/ day

# %%
def getTime(time):
    hour =  int(time.split(':')[0])
    minute = int(time.split(':')[1])
    return hour + minute/100.

def truncData(dataIn,mode):
    data = deepcopy(dataIn)
    firstDay = data.irow(0)['day']
    firstTime = getTime(data.irow(0)['time'])
    limit = len(data)
    pos = limit-1
    if mode == "hour":
        while getTime(data.irow(pos)['time']) > firstTime or getTime(data.irow(pos-1)['time']) < firstTime:
            pos -= 1
    elif mode == "day":
        while getTime(data.irow(pos)['time']) > firstTime or getTime(data.irow(pos-1)['time']) < firstTime or firstDay !=data.irow(pos-1)['day']:
                pos -= 1
                
    dayDiff = parser.parse(data.irow(pos)['created_at']).timetuple().tm_yday - parser.parse(data.irow(0)['created_at']).timetuple().tm_yday
    timeLim = 7*(mode=='day')+1*(mode=='hour')
    if dayDiff < timeLim:
        print "Cannot truncate to %s*n complete days, using full data range instead" % timeLim
        pos =  limit
        
    return data[:pos]

# %% [markdown]
# ### Hourly histogram functions

# %%
def chartHourly(dataIn, timeShift):
    data = truncData(dataIn['data'],"hour")
    dates = data['created_at']
    dates = [parser.parse(date) for date in dates]
    hour_list = [(t+timedelta(hours=timeShift)).hour for t in dates]
    numbers=[x for x in xrange(0,25)]
    labels=map(lambda x: str(x), numbers)
    plt.xticks(numbers, labels)
    plt.title(dataIn['name'],size = 12)
    plt.xlabel("Hour (GMT %s)" % timeShift)
    plt.ylabel("Tweets")
    plt.hist(hour_list,bins=numbers, alpha=0.5, align='mid')
    plt.show()
    
def groupHourly(dataGroup, names, title, timeShift, stackMe):
    toPlot = []
    for dataIn in dataGroup:
        data = truncData(dataIn['data'],"hour")
        dates = data['created_at']
        dates = [parser.parse(date) for date in dates]
        hour_list = [(t+timedelta(hours=timeShift)).hour for t in dates]
        toPlot.append(hour_list)
        numbers=[x for x in xrange(0,25)]
        labels=map(lambda x: str(x), numbers)
        plt.xticks(numbers, labels)
        plt.xlabel("Hour (GMT %s)" % timeShift)
        plt.ylabel("Tweets")
    plt.title(title,size = 12)
    plt.hist(toPlot,bins=numbers,stacked=stackMe, alpha=0.5, label=names, align='mid')
    plt.legend(names,"best")
    plt.show()

# %% [markdown]
# ### Daily histogram function

# %%
weekList = ['zero','Mon','Tue','Wed','Thu','Fri','Sat','Sun','null']
weekNum = [-1,0,1,2,3,4,5,6,7]

def chartDaily(dataIn, timeShift):
    data = truncData(dataIn['data'],"day")
    dates = data['created_at']
    dates = [parser.parse(date) for date in dates]
    dayList = [(t+timedelta(hours=timeShift)).weekday() for t in dates]
    plt.xticks(weekNum, weekList)
    plt.title(dataIn['name'],size = 12)
    plt.xlabel("Day (GMT %s)" % timeShift)
    plt.ylabel("Tweets")
    plt.hist(dayList,bins=weekNum,align='left',alpha=0.5)
    plt.show()
    
    
def groupDaily(dataGroup, names, title, timeShift, stackMe):
    toPlot = []
    for dataIn in dataGroup:
        data = truncData(dataIn['data'],"day")
        dates = data['created_at']
        dates = [parser.parse(date) for date in dates]
        dayList = [(t+timedelta(hours=timeShift)).weekday() for t in dates]
        toPlot.append(dayList)
        plt.xticks(weekNum, weekList)
        plt.title(dataIn['name'],size = 12)
        plt.xlabel("Day (GMT %s)" % timeShift)
        plt.ylabel("Tweets")
    plt.title(title,size = 12)
    plt.hist(toPlot,bins=weekNum,stacked=stackMe, alpha=0.5, label=names, align='left')
    plt.legend(names,"best")
    plt.show()

# %% [markdown]
# ### Plot distribution by day and time

# %%
def dailyDistributionPlot(dataIn,titles,bigTitle,timeShift,divFactor,overlay):
    """ draw the histogram of the daily distribution """
    ax = plt.figure(figsize=(18,6)).gca()
    merged = []
    prepped = [] 
    
    collected = deepcopy(dataIn)
    for pos in range(len(collected)):
        collected[pos] = collected[pos]['data']['created_at']
        collected[pos] = [parser.parse(date)+timedelta(hours=timeShift)for date in collected[pos]]
        
    for ytime in collected:
        numtime = [date2num(t) for t in list(ytime)] 
        merged += numtime
        prepped.append(numtime)
        
    first = num2date(min(merged))
    last = num2date(max(merged))
    
    hour = timedelta(hours=1) 
    minute = timedelta(minutes=1)
    
    firstRounded = first.replace(second=0,minute=0)
    lastRounded = last.replace(second=0,minute=0) + hour
    plotMin = date2num(firstRounded)
    plotMax = date2num(lastRounded)
    dateFirst = first.strftime("%m/%d/%y")
    dateLast = last.strftime("%m/%d/%y")
    timeSuffix = " from %s to %s" % (dateFirst,dateLast)
    
    difference = (lastRounded-firstRounded)
    hourBlocks = difference.days*24 + difference.seconds//3600
    if hourBlocks%2 != 0:
        plotMax = date2num(lastRounded + hour)
        hourBlocks += 1
    
    plotTitle = titles[0]
    for i in range(len(prepped)):
        if overlay:
            numtime = prepped[i]
            _, _, patches = plt.hist(numtime, bins=(hourBlocks)/divFactor, alpha=0.5, 
                                    stacked=False, range=(plotMin,plotMax))
    if not overlay:
        _, _, patches = plt.hist(prepped, bins=(hourBlocks)/divFactor, alpha=0.5, 
                                    stacked=True, range=(plotMin,plotMax))
    
        
    #tks = [num2date(p.get_x())+minute for p in patches] 
    #plt.xticks(tks,rotation=90,size = 8)
    plt.xlabel("Date/time (GMT %s)" % timeShift)
    plt.gca().set_xlim([plotMin,plotMax])
    plt.ylabel("Number of tweets")
    plt.legend(titles,"best")
    plt.title(bigTitle+timeSuffix,size=16)
    ax.xaxis.set_major_formatter(DateFormatter('%m/%d %H'))
    
    for pos in range(len(prepped)):
        print "%s: %s entries found" % (titles[pos],len(prepped[pos]))
        countHashTags(dataIn[pos]['data'],5)
        printSample(dataIn[pos]['data'],"",5)

# %% [markdown]
# ### Show n most popular hashtags

# %%
def countHashTags(data,number):
    entries = data['text']
    counts = dict()
    for entry in entries:
        words = entry.split(' ')
        for word in words:
            if word.startswith('#'):
                if word not in counts.keys():
                    counts[word] = 1
                else:
                    counts[word] += 1
    sortedCounts= sorted(counts.iteritems(), key=operator.itemgetter(-1))
    for count in reversed(sortedCounts[-number:]):
        print count

# %% [markdown]
# ### Tabulates destination link count from sample of shortened links

# %%
def checkLinks(data,n,shown):
    entries = data['text']
    links = set()
    counts = dict()
    domainCounts = dict()
    row = 0
    for entry in entries:
        words = entry.split(' ')
        for word in words:
            if word.startswith('http'):
                links.add(word)
    print len(links), "shortened URLs found, taking sample of size", n
    if type(n) is int:
        links = sample(links,n)
    for link in links:
        row += 1
        if row % 25 == 0:
            print "Entry",row,"out of",n,"complete,",len(counts),"destination links found with",len(domainCounts),'unique domains'
        sleep(0.1)
        try:
            linked = urllib.urlopen(link)
            if linked.getcode() == 200:
                word = str(linked.url)
                if word not in counts.keys():
                    counts[word] = 1
                    domain = '/'.join(word.split('/')[:3])+'/'
                    if domain not in domainCounts.keys():
                        domainCounts[domain] = 1
                    else:
                        domainCounts[domain] += 1
                else:
                    counts[word] += 1
                #print word
        except:
            None
    print '\n',len(counts.keys()), "destination URLs found"
    print len(domainCounts.keys()), "destination URL domains found"
    sortedCounts= sorted(counts.iteritems(), key=operator.itemgetter(-1))
    sortedDomainCounts= sorted(domainCounts.iteritems(), key=operator.itemgetter(-1))
    print "\nHighest Ranked Links:"
    for count in reversed(sortedCounts[-shown:]):
        print '\t',count
    print "\nHighest Ranked Domains:"
    for count in reversed(sortedDomainCounts[-shown:]):
        print '\t',count
    #return counts

# %% [markdown]
# ### General Tweet Volume NoVA area search of: {the, i, to, a, and, is, in, it, you, of, for, on, my}

# %%
chartHourly(novaAll, -5)
chartDaily(novaAll,-5)

# %% [markdown]
# ### Firearm Violence and Norovirus distribution by date * time

# %%
noroInf = getCatSub(allData['Virginia Norovirus Posts'],noroCats,2)
noroGIInf = getCatSub(allData['Virginia Norovirus Posts'],noroCats,3)
chartHourly(noroGIInf, -5)
groupHourly([noroInf,noroGIInf],['Infectious Illness','Infectious GI Illness'],'Virginia Norovirus Related Posts',-5,True)

# %%
gunEast = getGeoSub(allData['Firearm Violence Posts'],eTimeBox,'East Coast')
gunFirst = getCatSub(gunEast,gunCats,3)
gunMedia = getCatSub(gunEast,gunCats,2)
usaFirst = getCatSub(allData['Firearm Violence Posts'],gunCats,3)
usaMedia = getCatSub(allData['Firearm Violence Posts'],gunCats,2)
groupHourly([usaFirst,usaMedia],['First Hand','Media Related'],"USA Firearm Violence Related Posts",-5,True)
groupHourly([gunFirst,gunMedia],['First Hand','Media Related'],"East Coast Firearm Violence Related Posts",-5,True)

# %%
groupDaily([noroInf,noroGIInf],['Infectious Illness','Infectious GI Illness'],'Virginia Norovirus Related Posts',-5,True)
groupDaily([gunFirst,gunMedia],['First Hand','Media Related'],"East Coast Firearm Violence Related Posts",-5,True)

# %%
dailyDistributionPlot([usaFirst,usaMedia],['First hand reports','Media discussion'],"National Gun Violence Related Posts",-5,8,False)
# Out:
# First hand reports: 10869 entries found
# ('#NotOneMore', 26)
# ('#RHShooting', 18)
# ('#NRA', 15)
# ('#GH', 12)
# ('#CriminalMinds', 11)
# 	In other news: will people stop shooting other people #nooneisafe #shitiscrazy #SPUshooting
# 	She literally handled that as if he was shooting up heroin
# 	For fuck's sake - another school shooting? When are we not okay with this? Oh, right, never, because...
# 	@ATweeter my gun shot wound is fine how's urs?
# 	Niggas started shooting
#
#
# Media discussion: 14144 entries found
# ('#BREAKING:', 235)
# ('#BREAKING', 203)
# ('#shooting', 70)
# ('#Moncton', 64)
# ('#chsnews', 46)
# 	#BREAKING: Cobb Police responding to possible shooting at Kroger on Dallas Hwy.  We're on the way to...
# 	When the bar tender says the last shot is on him!!!! My man
# 	Loved shooting with the kids today!
# 	Police investigating shooting at Wave Rider Resort on Ocean Boulevard in Myrtle Beach
# 	Another bloody shooting, my prayers go out to the victims of the Seattle Pacific University Shooting...

# %%
troutFirst = getGeoSub(usaFirst,troutBox,'Troutdale')
troutMedia = getGeoSub(usaMedia,troutBox,'Troutdale')
dailyDistributionPlot([troutFirst,troutMedia],['First hand reports','Media discussion'],"Portland Metro Area (including Troutdale) Gun Violence Related Posts",-5,8,False)
# Out:
# First hand reports: 85 entries found
# ('#motorcycle', 1)
# ('#ReynoldsShooting', 1)
# ('#gofuckyourself', 1)
# ('#MLS', 1)
# ('#rhshooting', 1)
# 	@ATweeter - crazy is crazy baby...another campus shooting...ive heard 2 serious so far..
# 	how sideways is the conversation when we're relieved that less than a handful of people got shot?
# 	Uggghhhh just heard about the shooting at SPU...such a great campus...thoughts go out to friends/fam...
# 	@ATweeter Keeyyyyraaizzzzt, the article on the wal mart shooting frustrates me.  These people talked...
# 	Well fuck me...the high school I went to got shot up today. It was only a matter of time. #ReynoldsS...
#
#
# Media discussion: 191 entries found
# ('#LiveonK2', 17)
# ('#RHShooting', 11)
# ('#liveonk2', 10)
# ('#LiveOnK2', 10)
# ('#pdx911', 9)
# 	Milwaukie police involved in officer-involved shooting at SE Johnson Ck Blvd and 37th Ave during tra...
# 	Troutdale Police Chief: Emilio Hoffman, victim, shot inside the boys' locker room. Shooter found in ...
# 	My thoughts and prayers to everyone who was affected by the shooting this morning at Reynold's High ...
# 	Police say 2 people dead, one injured at early morning domestic shooting in Vancouver. NE 52nd block...
# 	JUST IN: Hospital officials say 3rd Vancouver shooting victim is in critical condition in the ICU. H...

# %%
peakTroutFirst = trimRange('6/8/2014 12AM GMT -5','6/12/2014 12AM GMT -5',troutFirst)
peakTroutMedia = trimRange('6/8/2014 12AM GMT -5','6/12/2014 12AM GMT -5',troutMedia)
dailyDistributionPlot([peakTroutFirst,peakTroutMedia],['First hand reports','Media discussion'],"Portland Metro Area (including Troutdale) Gun Violence Related Posts",-5,0.5,False)
# Out:
# First hand reports: 35 entries found
# ('#ReynoldsShooting', 1)
# ('#rhshooting', 1)
# ('#PrayForReynoldsHS', 1)
# ('#Blood', 1)
# ('#Portland,', 1)
# 	A sad day.  Another school shooting, just down the road from where I live.  A lot of people nowadays...
# 	It's a strange world we live in. Wake up and get told "there's been a school shooting" like its no b...
# 	Another shooting spree. We need one of those signs for tracking them: _ Days Since Last Shooting...o...
# 	Heartbroken over the shooting in troutdale. What is wrong with people
# 	I just heard about the shooting at the club.
#
#
# Media discussion: 91 entries found
# ('#RHShooting', 11)
# ('#LiveonK2', 8)
# ('#liveonk2', 5)
# ('#reynoldshighschool', 4)
# ('#Breaking:', 2)
# 	Thoughts are with the victim of the Reynolds school shooting. Another young life taken. #rhshooting
# 	Breaking: two confirmed dead in Vancouver shooting.
# 	3 people reported shot in Hazel Dell, @ATweeter on the way and will have live pictures. #liveonk2
# 	Wednesday was supposed to be the last day of school for students at #reynoldshighschool. Instead a s...
# 	From Iran:Praying for my home state #Oregon and all those affected by the #Reynolds High School shoo...

# %%
chiFirst = getGeoSub(usaFirst,chiBox,'Chicago')
chiMedia = getGeoSub(usaMedia,chiBox,'Chicago')
dailyDistributionPlot([chiFirst,chiMedia],['First hand reports','Media discussion'],"Chicago Gun Violence Related Posts",-5,8,False)
# Out:
# First hand reports: 335 entries found
# ('#Chicago', 7)
# ('#ChicagoScanner', 4)
# ('#chiraq', 2)
# ('#EastGarfieldPark', 2)
# ('#Chiraq', 2)
# 	Went out n shot the 40 last night
# 	Niggas Upping Guns Aint Shooting Lames
# 	@ATweeter guy got shot in the eyeball
# 	You know your fear is too real when you're more scared of it than being shot or stabbed
# 	Somebody just got shot on 16th &amp; Avers..
#
#
# Media discussion: 289 entries found
# ('#Chicago', 31)
# ('#CrimeIsDown', 16)
# ('#Chiraq', 15)
# ('#chicagoscanner', 10)
# ('#HumboldtPark', 4)
# 	Manhunt underway in city of #Moncton, in Canadian province of #NewBrunswick, after 3 #police officer...
# 	Poss. shooting victim headed to the ER
# 	@ATweeter This "mass shooting" happened in my area &amp; is not isolated. Not natl news since no one...
# 	Next on CBS2: 6 people shot outside a #Chicago laundromat. @ATweeter is live with an update on their...
# 	2 people shot 321 E. 136th St #Chicago #Riverdale #Chiraq

# %%
novaFirst = getGeoSub(usaFirst,novaBox,'NoVA')
novaMedia = getGeoSub(usaMedia,novaBox,'NoVA')
dailyDistributionPlot([novaFirst,novaMedia],['First hand reports','Media discussion'],"NoVA Area Gun Violence Related Posts",-5,8,False)
# Out:
# First hand reports: 5 entries found
# 	I GOT SHOT
# 	Did I just hear a gun shot in admo? Shit might be too real
# 	PUEY PUEY PUEY GUN SHOT DEAD ASS
# 	PUEY PUEY PUEY GUN SHOT
# 	@ATweeter oh man, I kind of want to guess what it is. Do I have a shot?
#
#
# Media discussion: 3 entries found
# ('#internationalstudents', 1)
# ('#guncontrolnow', 1)
# 	Just watched a Greys episode about a shooting at Seattle Pacific University and just saw on the news...
# 	Ukraine says it will launch an investigation into a fatal shooting in the east of the country which ...
# 	Should US schools include Surviving a Campus Shooting in #internationalstudents orientations? Outrag...

# %%
print "NOTE: From Feb 15 - April 21, only infectious GI Illness tweets were kept via current definitions"
dailyDistributionPlot([noroInf,noroGIInf],['Infectious Illness','Infectious GI Illness'],"Virginia Gastrointestinal Illness Related Posts",-5,24,False)
# Out:
# NOTE: From Feb 15 - April 21, only infectious GI Illness tweets were kept via current definitions
# Infectious Illness: 2411 entries found
# ('#quotes', 12)
# ('#barf', 6)
# ('#puke', 4)
# ('#fml', 4)
# ('#RAW', 3)
# 	I am so sick of hearing about Justin Bieber.
# 	Feel so sick man
# 	Feel so sick today
# 	I am so sick of this
# 	I am so sick of everything
#
#
# Infectious GI Illness: 16422 entries found
# ('#NowPlaying', 27)
# ('#barf', 26)
# ('#sick', 26)
# ('#fml', 15)
# ('#norovirus', 15)
# 	My daughter keep throwing up
# 	Finally getting back to grading and #sextivism class prep after dealing with a sick baby. Hoping Roy...
# 	The first stormy evening of summer calls for two fingers of whiskey, upset stomach be damned.
# 	ive thrown up three times today and i dont know whats wrong i definitely havent eaten enough in the ...
# 	Does anyone know yet why a person with doodoo-breath doesn't smell the stench spewing right under th...

# %%
peakNoroInf = trimRange('1/1/2014 12AM GMT -5','2/10/2014 12AM GMT -5',noroInf)
peakNoroGIInf = trimRange('1/1/2014 12AM GMT -5','2/10/2014 12AM GMT -5',noroGIInf)
dailyDistributionPlot([peakNoroInf,peakNoroGIInf],['Infectious Illness','Infectious GI Illness'],"Peak Virginia Gastrointestinal Illness Related Posts",-5,24,False)
# Out:
# Infectious Illness: 1358 entries found
# ('#barf', 4)
# ('#puke', 4)
# ('#fml', 3)
# ('#', 3)
# ('#sick', 3)
# 	I feel so sick
# 	I feel so sick
# 	Jerusalem - A mother and her two children sick from nausea and vomiting arrived at hospital in Jerus...
# 	I am so sick of snow!
# 	I feel so sick.
#
#
# Infectious GI Illness: 3075 entries found
# ('#sick', 6)
# ('#norovirus', 6)
# ('#SOTU', 5)
# ('#fml', 4)
# ('#mommyproblems', 3)
# 	Just turned on my TV and #RichKidsOfBeverlyHills was on. Gonna go puke now. Wtf is wrong with this c...
# 	Might throw up , but ill be here
# 	Not breathing the whole drive home bc of the puke aroma filled car, yay for being dd
# 	@ATweeter @ATweeter he is still throwing up.
# 	I like to sit in the front of roller coasters just in case someone decides to throw up

# %%
nrvInf = getGeoSub(noroInf,nrvBox,'NRV')
nrvGIInf = getGeoSub(noroGIInf,nrvBox,'NRV')
dailyDistributionPlot([nrvInf,nrvGIInf],['Infectious Illness','Infectious GI Illness'],"Virginia NRV Gastrointestinal Illness Related Posts",-5,24,False)
# Out:
# Infectious Illness: 37 entries found
# ('#itsucks', 1)
# ('#nofoodforaweek', 1)
# ('#', 1)
# ('#norovirus', 1)
# ('#nevereveragain', 1)
# 	Omg i feel so sick ....
# 	The heat makes me feel so sick it's not even a gross feelin it's head hurting and I want to barf fee...
# 	Do not follow where the path may lead. Go, instead, where there is no path and leave a trail. -Ralph...
# 	Killed it on mtn pass on the way home, made my friend throw up haha.
# 	I feel so sick.
#
#
# Infectious GI Illness: 365 entries found
# ('#LT', 4)
# ('#radford', 2)
# ('#yuck', 2)
# ('#sick', 2)
# ('#soclose', 1)
# 	I feel like I wanna throw up
# 	@ATweeter I dropped the D word this morning to get out of work....diarrhea. Sometimes you gotta do w...
# 	This stomach bug is made me feel like death. Thank God I am still at Jan's house so she can take car...
# 	Feel like I may throw up.
# 	Ugh if only I could throw up, I'd feel so much better

# %% [markdown]
# ### Vaccine Autism Highest Ranked Links, Domains, & Hashtags

# %%
checkLinks(vaccData['data'],500,15)
# Out:
# 3229 shortened URLs found, taking sample of size 500
# Entry
#  25 out of 500 complete, 17 destination links found with 16 unique domains
# Entry
#  50 out of 500 complete, 39 destination links found with 33 unique domains
# Entry
#  75 out of 500 complete, 57 destination links found with 49 unique domains
# Entry
#  100 out of 500 complete, 74 destination links found with 63 unique domains
# Entry
#  125 out of 500 complete, 93 destination links found with 77 unique domains
# Entry
#  150 out of 500 complete, 115 destination links found with 96 unique domains
# Entry
#  175 out of 500 complete, 133 destination links found with 108 unique domains
# Entry
#  200 out of 500 complete, 153 destination links found with 118 unique domains
# Entry
#  225 out of 500 complete, 171 destination links found with 135 unique domains
# Entry
#  250 out of 500 complete, 188 destination links found with 142 unique domains
# Entry
#  275 out of 500 complete, 203 destination links found with 152 unique domains
# Entry
#  300 out of 500 complete, 221 destination links found with 160 unique domains
# Entry
#  325 out of 500 complete, 242 destination links found with 170 unique domains
# Entry
#  350 out of 500 complete, 261 destination links found with 180 unique domains
# Entry
#  375 out of 500 complete, 277 destination links found with 190 unique domains
# Entry
#  400 out of 500 complete, 294 destination links found with 199 unique domains
# Entry
#  425 out of 500 complete, 312 destination links found with 205 unique domains
# Entry
#  450 out of 500 complete, 329 destination links found with 213 unique domains
# Entry
#  475 out of 500 complete, 351 destination links found with 224 unique domains
# Entry
#  500 out of 500 complete, 363 destination links found with 229 unique domains
# 364
#  destination URLs found
# 230 destination URL domains found
# Highest Ranked Links:
# 	('http://www.usatoday.com/story/news/nation/2014/04/06/anti-vaccine-movement-is-giving-diseases-a-2nd-life/7007955/', 17)
# 	('http://www.startribune.com/lifestyle/health/259155541.html', 8)
# 	('http://www.usatoday.com/story/news/nation/2014/04/24/cdc-vaccine-benefits/8094789/', 6)
# 	('http://www.slate.com/blogs/bad_astronomy/2014/04/13/jenny_mccarthy_responds_to_claims_she_s_not_antivax.html', 5)
# 	('http://www.amazon.co.uk/Viral-Upheaval-Virus-Sequence-Book-ebook/dp/B00ISWC8B6', 4)
# 	('http://www.usatoday.com/story/news/nation-now/2014/05/15/measles-vaccine-cancer-mayo-clinic/9115363/', 4)
# 	('http://www.motherjones.com/environment/2014/04/how-many-kids-die-vaccine-preventable-diseases', 4)
# 	('http://www.usatoday.com/story/opinion/2014/04/13/vaccines-measles-misinformation-risks-editorials-debates/7682093/', 3)
# 	('http://time.com/46914/vaccine-opponents-wrong/', 3)
# 	('http://philadelphia.cbslocal.com/2014/05/20/health-local-researchers-developing-mers-virus-vaccine/', 2)
# 	('http://mashable.com/2014/04/15/ebola-treatment/?utm_campaign=Mash-Prod-RSS-Feedburner-All-Partial&utm_cid=Mash-Prod-RSS-Feedburner-All-Partial&utm_medium=twitter&utm_source=dlvr.it', 2)
# 	('http://www.cdc.gov/flu/news/brazil-travelers-vaccinated.htm', 2)
# 	('http://www.bloomberg.com/news/2014-05-20/biggest-vaccine-charity-seeks-7-5-billion-for-5-year-push.html', 2)
# 	('http://www.ted.com/talks/mark_kendall_demo_a_needle_free_vaccine_patch_that_s_safer_and_way_cheaper?utm_source=twitter&source=twitter&utm_medium=social&utm_campaign=ios-share', 2)
# 	('http://www.historyofvaccines.org/content/articles/history-lyme-disease-vaccine', 2)
#
# Highest Ranked Domains:
# 	('https://twitter.com/', 14)
# 	('https://www.facebook.com/', 12)
# 	('http://www.fiercevaccines.com/', 11)
# 	('http://ow.ly/', 9)
# 	('http://www.usatoday.com/', 9)
# 	('http://mashable.com/', 8)
# 	('http://www.npr.org/', 7)
# 	('http://www.healio.com/', 6)
# 	('http://www.washingtonpost.com/', 6)
# 	('http://www.cdc.gov/', 5)
# 	('http://www.smithsonianmag.com/', 4)
# 	('http://www.theguardian.com/', 4)
# 	('http://t.co/', 4)
# 	('http://www.bbc.co.uk/', 4)
# 	('http://www.sabin.org/', 3)

# %%
countHashTags(vaccData['data'],20)
# Out:
# ('#vaccine', 390)
# ('#HIV', 186)
# ('#Vaccine', 138)
# ('#HPV', 73)
# ('#vaccines', 68)
# ('#HVAD', 64)
# ('#health', 61)
# ('#Gardasil', 53)
# ('#polio', 52)
# ('#vaccineswork', 49)
# ('#cancer', 48)
# ('#measles', 42)
# ('#malaria', 42)
# ('#pharma', 37)
# ('#MERS', 36)
# ('#endofmalaria', 36)
# ('#Vaccines', 35)
# ('#Africa', 34)
# ('#Cervarix', 34)
# ('#WEFAfrica', 34)
